# %%
import glob
import re
from math import sqrt, floor, ceil

import numpy as np
from scipy import stats

from matplotlib import pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable

from utils import Graph

colors = ['C0', 'C1']
field_strength = 500

# %%
file_tree = [{}, {}]

for i, d in enumerate([1, 3]):
    for file in glob.glob('diffusion/%id/%i/*.txt'%(d, field_strength)):
        key = int(re.search(r'(\d*)(?:V)', file).group(1))
        if (key in file_tree[i]):
            file_tree[i][key].append(file)
        else:
            file_tree[i][key] = [file]

# %%
for i, d in enumerate([1, 3]):
    for key, value in sorted(file_tree[i].items()):
        group = Graph(value)
        
        min_x_dist = np.amin(([np.amax(np.floor(k)) for k in group.x])) # The greatest x value all simulations have in common
        x_index = [np.where(np.floor(k)==min_x_dist)[0][0] for k in group.x] # The data lines where these x values first occur
        
        t_vals = [group.t[k][x_index[k]] for k in range(group.n)]
        z = np.abs(stats.zscore(t_vals))
        mask_array = np.zeros(len(t_vals), dtype=int)
        mask_array[np.where(z > 2)] = 1
        without_outliers = np.ma.masked_array(t_vals, mask=mask_array)
        
        t_var = np.var(without_outliers, ddof=1)
        v_avg = np.mean([(group.x[k][x_index[k]] / group.t[k][x_index[k]] * 1e3) for k in range(group.n)])
        
        print('Our V_d:', v_avg, '\n')
        print('Their V_d:', 1648, '\n')
        
        print('D_L measured with t (our V_d):', (t_var / min_x_dist) * v_avg**3 * 0.5 * 1e-8, "\n")
        
        print('D_L measured with t (their V_d):', (t_var / min_x_dist) * 1648**3 * 0.5 * 1e-8, "\n")
        
        '''
        r_array = [np.sqrt(group.y[k]**2 + group.z[k]**2) for k in range(group.n)]
        min_r_dist = np.amin(([np.amax(np.floor(k)) for k in r_array]))
        r_index = [np.where(np.floor(k)==min_r_dist)[0][0] for k in r_array]
        
        t_avg = sum([group.t[k][r_index[k]] for k in range(group.n)]) / group.n
        t2_avg = sum([group.t[k][r_index[k]]**2 for k in range(group.n)]) / group.n
        t_var = t2_avg - t_avg**2
        
        print(t_var, approx_var(group.t, r_index))
        
        v_avg = sum([(r_array[k][r_index[k]] / group.t[k][r_index[k]] * 1e3) for k in range(group.n)]) / group.n
        
        print('D_T measured with t (our V_d):', (t_var / min_r_dist) * v_avg**3 * 0.5 * 1e-8, "\n")
        
        x_avg = sum([group.x[k][-1] for k in range(group.n)]) / group.n
        x2_avg = sum([group.x[k][-1]**2 for k in range(group.n)]) / group.n
        x_var = x2_avg - x_avg**2
        
        print('D_L measured with x:', x_var / 20 * 1e1, "\n")
        
        y_avg = sum([group.y[k][-1] for k in range(group.n)]) / group.n
        y2_avg = sum([group.y[k][-1]**2 for k in range(group.n)]) / group.n
        y_var = y2_avg - y_avg**2
        
        z_avg = sum([group.z[k][-1] for k in range(group.n)]) / group.n
        z2_avg = sum([group.z[k][-1]**2 for k in range(group.n)]) / group.n
        z_var = z2_avg - z_avg**2
        
        plt.hist([group.x[k][-1] for k in range(group.n)])
        plt.show()
        
        plt.hist([group.y[k][-1] for k in range(group.n)])
        plt.show()
        
        plt.hist([group.z[k][-1] for k in range(group.n)])
        plt.show()
        
        print('D_T measured with x:', (y_var**2 + z_var**2)**0.5 / 20 * 1e1)
        
        for k in range(group.n):
            plt.plot(group.t[k], r_array[k])
        plt.title('Transversal Drift')
        plt.xlabel('ns')
        plt.ylabel('$\mu$m')
        plt.show()
        
        for k in range(group.n):
            plt.plot(group.t[k], group.x[k])
        plt.xlabel('ns')
        plt.title('Longitudinal Drift')
        plt.ylabel('$\mu$m')
        plt.show()
        '''
# Out:
# [10.1254, 10.99, 11.1194, 7.72773, 12.5009, 14.0502, 10.2291, 10.3993, 6.73016, 12.3405, 12.761, 11.6632, 9.78027, 13.0344, 10.9329, 9.269, 8.88836, 11.1976, 14.804, 12.5215, 8.13551, 10.4919, 19.6084, 14.0325, 10.0345, 11.3236, 10.2294, 11.4111, 11.2502, 17.2498, 6.99178, 16.9768, 11.9007, 11.3068, 8.74886, 13.8169, 9.08965, 14.4529, 11.7315, 11.3517, 7.9091, 11.3623, 8.35605, 13.9744, 12.3966, 13.6329, 8.09727, 10.9014, 8.14164, 10.9905, 9.30809, 7.24315]
# [10.1254 10.99 11.1194 7.72773 12.5009 14.0502 10.2291 10.3993 6.73016
#  12.3405 12.761 11.6632 9.78027 13.0344 10.9329 9.269 8.88836 11.1976
#  14.804 12.5215 8.13551 10.4919 -- 14.0325 10.0345 11.3236 10.2294 11.4111
#  11.2502 -- 6.99178 -- 11.9007 11.3068 8.74886 13.8169 9.08965 14.4529
#  11.7315 11.3517 7.9091 11.3623 8.35605 13.9744 12.3966 13.6329 8.09727
#  10.9014 8.14164 10.9905 9.30809 7.24315]
# Our V_d: 1223.6706578269873
#
# Their V_d: 1648
#
# D_L measured with t (our V_d): 4.940411451952262
#
# D_L measured with t (their V_d): 12.068161209295717

# %%
for i, d in enumerate([1, 3]):
    for key, value in sorted(file_tree[i].items()):
        group = Graph(value)
        
        fig = plt.figure(figsize=(16,8))
        
        sigma_squared_L = []
        sigma_squared_T1 = []
        sigma_squared_T2 = []
        t = []
        
        for k in range(0, len(group.t[0]), round(len(group.t[0]) / 100)):
            t.append(group.avg_t(k) * 1e-9)
            sigma_squared_L.append(group.variance_x(k) * 1e-8)
            sigma_squared_T1.append(group.variance_y(k) * 1e-8)
            sigma_squared_T2.append(group.variance_z(k) * 1e-8)
        
        slope_L, intercept_L, r_value_L, p_value_L, std_err_L = stats.linregress(t, sigma_squared_L)
        slope_T1, intercept_T1, r_value_T1, p_value_T1, std_err_T1 = stats.linregress(t, sigma_squared_T1)
        slope_T2, intercept_T2, r_value_T2, p_value_T2, std_err_T2 = stats.linregress(t, sigma_squared_T2)
            
        plt.title('%iD, %i V/cm   $D_L = $%.2f'%(d, field_strength, slope_L) + '   $D_{T_y} = $%.2f'%slope_T1 + '   $D_{T_z} = $%.2f'%slope_T2)
            
        plt.plot(t, sigma_squared_L, label='$\sigma_L^2$')
        plt.plot(t, sigma_squared_T1, label='$\sigma_{T_y}^2$')
        plt.plot(t, sigma_squared_T2, label='$\sigma_{T_z}^2$')
        
        plt.xlabel('t [s]')
        plt.ylabel('$\sigma^2$ [cm$^2$]')
        
        plt.legend()
        
        plt.grid()
        plt.show()

# %% [markdown]
# Our transverse and longitudinal diffusion coefficients are calculated by determining the slopes of the lines above, which show the change in positional variation over time for a group of 100 electrons. The values we should check against are available at https://lar.bnl.gov/properties/index.html#e-trans.
#
# For our own reference, plots of distributions in position are displayed below.

# %%
for i, d in enumerate([1, 3]):
    for key, value in sorted(file_tree[i].items()):
        group = Graph(value)
        
        for k in range(0, len(group.t[0]), round(len(group.t[0]) / 9)):
            x = []
            y = []
            z = []
            for j in range(group.n):
                x.append(group.x[j][k])
                y.append(group.y[j][k])
                z.append(group.z[j][k])
            
            fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(16, 6))

            plots = [[x, y], [x, z], [y, z]]
            labels = [['x', 'y'], ['x', 'z'], ['y', 'z']]

            for j, subplot in enumerate([ax1, ax2, ax3]):
                subplot.scatter(plots[j][0], plots[j][1], color=colors[i])
                subplot.set_aspect(1.)

                subplot.set_xlabel(labels[j][0] + ' [$\mu$m]')
                subplot.set_ylabel(labels[j][1] + ' [$\mu$m]')

                divider = make_axes_locatable(subplot)
                axHistx = divider.append_axes("top", 1.2, pad=0.1, sharex=subplot)
                axHisty = divider.append_axes("right", 1.2, pad=0.1, sharey=subplot)

                axHistx.xaxis.set_tick_params(labelbottom=False)
                axHisty.yaxis.set_tick_params(labelleft=False)

                binwidth = 1
                xymax = max(np.max(np.abs(plots[j][0])), np.max(np.abs(plots[j][1])))
                lim = (int(20) + 1)*binwidth

                bins = np.arange(-lim, lim + binwidth, binwidth)
                axHistx.hist(plots[j][0], bins=bins, histtype='stepfilled', color=colors[i])
                axHistx.set_title('%iD - %0.3f'%(d, group.t[0][k]) + ' ns')
                axHisty.hist(plots[j][1], bins=bins, orientation='horizontal', histtype='stepfilled', color=colors[i])

                axHistx.set_yticks([0, 5, 10])
                axHisty.set_xticks([0, 5, 10])

            plt.draw()     
            plt.show()

# %%
for i, d in enumerate([1, 3]):
    for key, value in sorted(file_tree[i].items()):
        group = Graph(value)
        
        for k in range(0, len(group.t[0]), round(len(group.t[0]) / 9)):
            x = []
            y = []
            z = []
            for j in range(group.n):
                x.append(group.x[j][k])
                y.append(group.y[j][k])
                z.append(group.z[j][k])
            
            fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize=(16,4))

            plots = [x, y, z]
            labels = ['x', 'y', 'z']

            for j, subplot in enumerate([ax1, ax2, ax3]):
                subplot.hist(plots[j], color=colors[i], rwidth=0.6, bins=range(-40, 40, 1))
                subplot.set_xlim(-40, 40)
                subplot.set_title('%iD - '%d + labels[j] + '-coordinate at %0.3f'%group.t[0][k] + ' ns')
                subplot.set_xlabel(labels[j] + ' [$\mu$m]')
                subplot.set_ylabel('Number of Electrons')
                
            plt.show()
